# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importing the required Dataset

# %%
df = pd.read_csv("Simulation_Dataa.csv")
df.head(5)
# Out:
#                 _id        date          time   latitude   longitude  \
# 0  ::1671149942.329  2022-12-15  19:19:02.329  37.954096 -107.903543
# 1  ::1671149942.351  2022-12-15  19:19:02.351  37.954096 -107.903543
# 2  ::1671149942.373  2022-12-15  19:19:02.373  37.954096 -107.903543
# 3  ::1671149942.395  2022-12-15  19:19:02.395  37.954096 -107.903543
# 4  ::1671149942.419  2022-12-15  19:19:02.419  37.954096 -107.903543
#
#    gpsAltitude  absoluteAltitude  trueHeading  pitch   roll  ...  \
# 0      9060.92              0.05       15.923  0.690  0.262  ...
# 1      9060.95              0.08       15.897  0.780  0.488  ...
# 2      9060.98              0.11       15.861  0.900  0.759  ...
# 3      9061.00              0.13       15.811  1.043  1.042  ...
# 4      9061.00              0.14       15.749  1.192  1.311  ...
#
#    normalAcceleration  longitudinalAcceleration  antiTorquePedalPosition  \
# 0               0.633                     0.423                  -14.022
# ...

# %% [markdown]
# ### Summary of the dataset

# %%
df.describe()
# Out:
#            latitude     longitude   gpsAltitude  absoluteAltitude  \
# count  77043.000000  77043.000000  77043.000000      77043.000000
# mean      37.950109   -107.879406   9343.292293        281.685052
# std        0.007871      0.033826    310.055296        437.673395
# min       37.930688   -107.919861   9018.220000         -0.250000
# 25%       37.948915   -107.903646   9075.100000          0.690000
# 50%       37.952922   -107.894855   9302.900000         38.340000
# 75%       37.955923   -107.866291   9487.565000        381.320000
# max       37.958849   -107.799158  10251.330000       2156.510000
#
#         trueHeading         pitch          roll           yaw   groundSpeed  \
# count  77043.000000  77043.000000  77043.000000  77043.000000  77043.000000
# mean     132.715092      2.579022      1.852943    132.693346     28.541706
# std      104.102786      3.801096      5.725509    104.146487     35.067203
# ...

# %% [markdown]
# ### To check the size of the dataset

# %%
df.shape
# Out:
# (77043, 35)

# %% [markdown]
# ### To check whether there are any null values in the dataset ( No null values )

# %%
df.isnull().sum()
# Out:
# _id                         0
# date                        0
# time                        0
# latitude                    0
# longitude                   0
# gpsAltitude                 0
# absoluteAltitude            0
# trueHeading                 0
# pitch                       0
# roll                        0
# yaw                         0
# groundSpeed                 0
# trueAirspeed                0
# climbOrDescentRate          0
# pilotRadioAltitude          0
# copilotRadioAltitude        0
# groundTrack                 0
# rollRate                    0
# pitchRate                   0
# yawRate                     0
# turnRate to degPerSec       0
# rollAcceleration            0
# pitchAcceleration           0
# yawAcceleration             0
# lateralAcceleration         0
# normalAcceleration          0
# longitudinalAcceleration    0
# antiTorquePedalPosition     0
# throttlePosition            0
# hasParkingBrakeEngaged      0
# hasLandingGearDown          0
# ...

# %% [markdown]
# ### To see the Data Types of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77043 entries, 0 to 77042
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _id                       77043 non-null  object
#  1   date                      77043 non-null  object
#  2   time                      77043 non-null  object
#  3   latitude                  77043 non-null  float64
#  4   longitude                 77043 non-null  float64
#  5   gpsAltitude               77043 non-null  float64
#  6   absoluteAltitude          77043 non-null  float64
#  7   trueHeading               77043 non-null  float64
#  8   pitch                     77043 non-null  float64
#  9   roll                      77043 non-null  float64
#  10  yaw                       77043 non-null  float64
#  11  groundSpeed               77043 non-null  float64
#  12  trueAirspeed              77043 non-null  float64
# ...
